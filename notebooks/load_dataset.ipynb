# %%
from cv_py.data.resource import load

# %%
d = load("cord19_cdcs")

# %%
d.head()
# Out:
#          microsoft_academic_paper_id_url    license has_full_text       pmcid  \
# cord_uid
# 000q5l5n                                      cc-by          TRUE  PMC6562389
# 000tfenb                                      cc-by          TRUE  PMC5700739
# 001skdgj                                        unk          TRUE  PMC2562712
# 001wbz6e                                  els-covid          TRUE
# 0021yo3o                                  els-covid          TRUE  PMC7126920
#
#                                                         pid  \
# cord_uid
# 000q5l5n  https://127.0.0.1/pid/rest/local/cdcs/Seroprev...
# 000tfenb  https://127.0.0.1/pid/rest/local/cdcs/Prevalen...
# 001skdgj  https://127.0.0.1/pid/rest/local/cdcs/PERSISTE...
# 001wbz6e  https://127.0.0.1/pid/rest/local/cdcs/Pharmace...
# 0021yo3o  https://127.0.0.1/pid/rest/local/cdcs/Procalci...
#
#                                   source_x_url  \
# cord_uid
# 000q5l5n  https://www.ncbi.nlm.nih.gov/pubmed/
# ...

# %%
d.journal.value_counts().compute()
# Out:
#                                                        4748
# Journal of Virology                                    1763
# PLoS One                                               1628
# Virology                                                929
# Emerg Infect Dis                                        812
#                                                        ...
# Social Learning Systems and Communities of Practice       1
# Social Network Analytics                                  1
# Social Networks                                           1
# Immunology Guidebook                                      1
# Iran J Radiol                                             1
# Name: journal, Length: 6217, dtype: int64

# %%
d.pid.value_counts().compute().head()
# Out:
# https://127.0.0.1/pid/rest/local/cdcs/zw03w767_47186becbce3a40faf3db8695c54eb70403aa99e                                        1
# https://127.0.0.1/pid/rest/local/cdcs/Effects_of_Atypical_Infections_with_Mycoplasma_and_Chlamydia_on_Asthma                   1
# https://127.0.0.1/pid/rest/local/cdcs/Effects_of_distribution_of_infection_rate_on_epidemic_models                             1
# https://127.0.0.1/pid/rest/local/cdcs/Effects_of_disinfection_on_the_molecular_detection_of_porcine_epidemic_diarrhea_virus    1
# https://127.0.0.1/pid/rest/local/cdcs/Effects_of_different_sampling_solutions_on_the_survival_of_bacteriophages_in_bubbling    1
# Name: pid, dtype: int64
