# %%
from cv_py.data.resource import load

# %%
d = load("cord19_cdcs")

# %%
d.head()
# Out:
#                                        pubmed_id who_no_covidence_url  \
# pid
# https://127.0.0.1/pid/rest/local/cdcs/
# https://127.0.0.1/pid/rest/local/cdcs/
# https://127.0.0.1/pid/rest/local/cdcs/
# https://127.0.0.1/pid/rest/local/cdcs/
# https://127.0.0.1/pid/rest/local/cdcs/
#
#                                                                               license_url  \
# pid
# https://127.0.0.1/pid/rest/local/cdcs/  https://www.elsevier.com/about/policies/open-a...
# https://127.0.0.1/pid/rest/local/cdcs/  https://www.elsevier.com/about/policies/open-a...
# https://127.0.0.1/pid/rest/local/cdcs/  https://www.elsevier.com/about/policies/open-a...
# https://127.0.0.1/pid/rest/local/cdcs/  https://www.elsevier.com/about/policies/open-a...
# https://127.0.0.1/pid/rest/local/cdcs/  https://www.elsevier.com/about/policies/open-a...
#
#                                                                                   journal  \
# pid
# ...

# %%
d.journal.value_counts().compute()
# Out:
#                                                            3952
# Journal of Virology                                        1732
# PLoS One                                                   1566
# Virology                                                    865
# Emerg Infect Dis                                            746
#                                                            ...
# Korean J Ophthalmol                                           1
# Research in International Business and Finance                1
# Research in Microbiology                                      1
# Nature Structural & Molecular Biology                         1
# International Journal of Oral and Maxillofacial Surgery       1
# Name: journal, Length: 4857, dtype: int64

# %%
d.index.value_counts().compute().head()
# Out:
# https://127.0.0.1/pid/rest/local/cdcs/               157
# https://127.0.0.1/pid/rest/local/cdcs/Erratum          6
# https://127.0.0.1/pid/rest/local/cdcs/Commentary       6
# https://127.0.0.1/pid/rest/local/cdcs/Abkrzungen       5
# https://127.0.0.1/pid/rest/local/cdcs/Corrections      4
# Name: pid, dtype: int64
